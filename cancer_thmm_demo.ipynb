# %% [markdown]
# Cancer cell features
# - DINO embedding of phase and fluorescent channel of a surrounding crop
# - Area of nucleus in fluores chan
# - Circularity, perimeter etc
# - Intensity distribution within nucleus - is fluorescence concentrated or diffuse (std of pixel intensity?)
